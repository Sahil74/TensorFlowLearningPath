# %% [markdown]
# # Introduction to regression with neural netwrok in tf
#
# regresson definition (by daniel) =  predicting a numerical variable based on some other combination of variables, even shorter.. predicting a number.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %% [markdown]
# ## creating data to view and fit

# %%
 import numpy as np 
 import matplotlib.pyplot as plt

 #create features
 X = np.array([-7.0,-4.0,-1.0,2.0,5.0,8.0,11.0,14.0])

 #create labels
 y = np.array([3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0])

 #visulize it
 plt.scatter(X,y)

# %%
y == X+10 #relationship in our data
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ##input and output shape

# %%
# create a demo tensor for our house price
house_info = tf.constant(['bedroom','bathroom','garage'])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
X = tf.constant(X)
y = tf.constant(y)
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics=['mae'])

# %%
model.fit(X,y,epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 3s 3s/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/5
# 1/1 [==============================] - 0s 6ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/5
# 1/1 [==============================] - 0s 3ms/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/5
# 1/1 [==============================] - 0s 14ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/5
# 1/1 [==============================] - 0s 3ms/step - loss: 10.9748 - mae: 10.9748

# %%
#check x,y
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
model.predict([17.0])
# Out:
# array([[12.716021]], dtype=float32)

# %%
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(50),
                             tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.Adam(lr=0.01),
              metrics=['mae'])
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 1/1 [==============================] - 0s 273ms/step - loss: 14.6466 - mae: 14.6466
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 13.9532 - mae: 13.9532
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.2602 - mae: 13.2602
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.5658 - mae: 12.5658
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 11.8674 - mae: 11.8674
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.1621 - mae: 11.1621
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.4475 - mae: 10.4475
# Epoch 8/100
# ...

# %%
model.predict([17.0])
# Out:
# array([[26.434662]], dtype=float32)

# %% [markdown]
# when it comes to build model experiment experiment experiment
#                  evaluate model visulize visulize visulize
#
# * the data = what data are we working with? what does it look like?
# * the model itselff = what does our model look like?
# * the training of a model - how does a model perform while it learns?
# * the prediction of the model = how do the predictions of a model lineup against the ground truth (the original labels)

# %%
#make a bifgger dataset
X = tf.range(-100,100,4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
# make labels for the dataset
y = X+10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %% [markdown]
# ## the 3 sets
#
# * training set = the model learns from this data, which is typically 70-80% of the data you have availabel.
# * validation set - the model gets tuned on this data, which is typically 10-15%
# * test-set = the model gets evaluated on this data to test what is has learned, this set is typically 10-15%

# %%
#X = tf.constant(X)
#y = tf.constant(y)
#X,y

# %%
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
## normal train test split not working why?
X_train = X[:40] 
X_test = X[40:]

y_train = y[:40]
y_test =y[40:]

# %%
plt.figure(figsize=(10,7))
plt.scatter(X_train,y_train,c='b',label='Training data')
plt.scatter(X_test,y_test,c='g',label='Test data')
plt.legend()

# %%
#lets have to look at how to build neural network
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,optimizer =  tf.keras.optimizers.SGD(), metrics=['mae'])

#model.fit(X_train,y_train,epochs=100)

# %% [markdown]
# ## visulize the model

# %%
#model.summary()

# %%
tf.random.set_seed(42)
#lets have a look at how to build a neural network for our data
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(10,input_shape = [1],name='input_layer'),
                             tf.keras.layers.Dense(1,name='output_layer')
],name='model_1')

model.compile(loss = tf.keras.losses.mae,optimizer =  tf.keras.optimizers.SGD(), metrics=['mae'])

#model.fit(X_train,y_train,epochs=100)

# %%
model.summary()
#want to learn params info go mit introduction to dl
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (Dense)          (None, 10)                20
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Total params = total num of parameters in the model
# * trainable params = these are the params the model can update as it trains.
# * non-trainable params = these params aren't updated during training ..(transfer learning)

# %%
model.fit(X_train,y_train,epochs=100,verbose=0) #verbose for display running model

# %%
from tensorflow.keras.utils import plot_model
plot_model(model = model,show_shapes =True)

# %% [markdown]
# ## visulizing our model prediction

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[ 70.55219 ],
#        [ 75.139915],
#        [ 79.72764 ],
#        [ 84.31536 ],
#        [ 88.90308 ],
#        [ 93.49081 ],
#        [ 98.07853 ],
#        [102.66626 ],
#        [107.253975],
#        [111.841705]], dtype=float32)

# %%
def plot_prediction(train_data =X_train,
                    train_labels = y_train,
                    test_data = X_test,
                    test_labels= y_test,
                    predictions = y_pred):
  plt.figure(figsize=(10,7)) 
  plt.scatter(train_data, train_labels,c = 'b', label='Training data')
  plt.scatter(test_data,test_labels, c= 'g', label='Testing data')
  plt.scatter(test_data,predictions, c='r', label='Prediciton')
  plt.legend()

# %%
plot_prediction()

# %%
#evalauting out model's prediction with regressions evaluation metrics
model.evaluate(X_test,y_test)
# Out:
# 1/1 [==============================] - 0s 99ms/step - loss: 3.1969 - mae: 3.1969
# [3.196946620941162, 3.196946620941162]

# %%
#calcculate mae
from sklearn.metrics import mean_absolute_error 
mae = mean_absolute_error(y_test,y_pred)
mae
# Out:
# 3.196946716308594

# %%
# y_pred and y_test shape are not same
tf.squeeze(y_pred)
#another method mae
mae_2 = tf.metrics.mean_absolute_error(y_true = y_test, y_pred = tf.squeeze(y_pred))
mae_2
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.1969466>

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
#mse
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
mse
#another method mse
mse_2 = tf.metrics.mean_squared_error(y_true = y_test, y_pred = tf.squeeze(y_pred))
mse_2
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=13.070175>

# %%
def mse(y_test,y_pred):
  return tf.metrics.mean_squared_error(y_true= y_test,
                                       y_pred = tf.squeeze(y_pred))
def mae(y_test,y_pred):
  return tf.metrics.mean_absolute_error(y_true= y_test,
                                       y_pred = tf.squeeze(y_pred))

# %% [markdown]
# ## running experience to improve model
# * get more data
# * make model larger (increase layers,units)
# * train for longer
#
# model1 =1 layer 100 epochs
# model2 =2 layer 100 epochs
# model3 =2 layer 500 epochs

# %%
tf.random.set_seed(42)

model_1 = tf.keras.Sequential([
                               tf.keras.layers.Dense(1)
])

model_1.compile(loss = tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.SGD(),
                metrics = ["mae"])
model_1.fit(X_train,y_train, epochs =100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 6ms/step - loss: 15.9024 - mae: 15.9024
# Epoch 2/100
# 2/2 [==============================] - 0s 7ms/step - loss: 11.2837 - mae: 11.2837
# Epoch 3/100
# 2/2 [==============================] - 0s 6ms/step - loss: 11.1074 - mae: 11.1074
# Epoch 4/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.2990 - mae: 9.2990
# Epoch 5/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.1677 - mae: 10.1677
# Epoch 6/100
# 2/2 [==============================] - 0s 5ms/step - loss: 9.4303 - mae: 9.4303
# Epoch 7/100
# 2/2 [==============================] - 0s 5ms/step - loss: 8.5704 - mae: 8.5704
# Epoch 8/100
# 2/2 [==============================] - 0s 5ms/step - loss: 9.0442 - mae: 9.0442
# Epoch 9/100
# 2/2 [==============================] - 0s 3ms/step - loss: 18.7517 - mae: 18.7517
# Epoch 10/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.1142 - mae: 10.1142
# Epoch 11/100
# ...

# %%
#make and plot predictions for model_1
y_preds_1 = model_1.predict(X_test)
plot_prediction(predictions=y_preds_1)

# %%
 #calculate model_1 evaluation metrics
 mae_1 = mae(y_test, y_preds_1)
 mse_1 = mse(y_test, y_preds_1)
 mae_1, mse_1
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=18.745327>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=353.5734>)

# %% [markdown]
# ###model_2

# %%
tf.random.set_seed(42)
model_2 = tf.keras.Sequential([
                                      tf.keras.layers.Dense(10),
                                      tf.keras.layers.Dense(1)
])
model_2.compile(loss= tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.SGD(),
                metrics=["mse"])
model_2.fit(X_train,y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 6ms/step - loss: 27.4058 - mse: 1084.1481
# Epoch 2/100
# 2/2 [==============================] - 0s 4ms/step - loss: 24.6339 - mse: 777.9203
# Epoch 3/100
# 2/2 [==============================] - 0s 6ms/step - loss: 29.8935 - mse: 1334.8955
# Epoch 4/100
# 2/2 [==============================] - 0s 5ms/step - loss: 27.4055 - mse: 1106.8035
# Epoch 5/100
# 2/2 [==============================] - 0s 6ms/step - loss: 14.9463 - mse: 281.1077
# Epoch 6/100
# 2/2 [==============================] - 0s 4ms/step - loss: 11.8819 - mse: 168.6621
# Epoch 7/100
# 2/2 [==============================] - 0s 6ms/step - loss: 11.1988 - mse: 151.3508
# Epoch 8/100
# 2/2 [==============================] - 0s 6ms/step - loss: 11.0910 - mse: 160.3745
# Epoch 9/100
# 2/2 [==============================] - 0s 6ms/step - loss: 40.4763 - mse: 2586.0081
# Epoch 10/100
# 2/2 [==============================] - 0s 7ms/step - loss: 27.8687 - mse: 1094.4379
# ...

# %%
# make and plot prediction
y_preds_2 = model_2.predict(X_test)
plot_prediction(predictions=y_preds_2)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c27d9c950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#calculate the evaluation metrics
mae_2 = mae(y_test, y_preds_2)
mse_2 = mse(y_test, y_preds_2)
mae_2, mse_2
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=3.1969466>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=13.070175>)

# %% [markdown]
# ### model_3

# %%
tf.random.set_seed(42)
model_3 =tf.keras.Sequential([
                              tf.keras.layers.Dense(10),
                              tf.keras.layers.Dense(1)
])
model.compile(loss= tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics=['mse'])
model.fit(X_train,y_train, epochs=200,verbose=0)

# %%
#make and plot predicitons
y_preds_3 = model_3.predict(X_test)
plot_prediction(predictions=y_preds_3)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7c288ba4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
mae_3 = mae(y_test,y_preds_3)
mse_3 = mse(y_test,y_preds_3)

# %% [markdown]
# ### compare results

# %%
import pandas as pd
model_results = [['model_1',mae_1.numpy(), mse_1.numpy()],
                 ['model_2',mae_2.numpy(), mse_2.numpy()],
                 ['model_3',mae_3.numpy(), mse_3.numpy()]]
all_results = pd.DataFrame(model_results, columns= ['model', 'mae', 'mse'])
all_results
# Out:
#      model        mae          mse
# 0  model_1  18.745327   353.573395
# 1  model_2   3.196947    13.070175
# 2  model_3  59.024841  3536.077637

# %% [markdown]
# * tensorboard = a component of the tensorflow lib to help track modelling experiments
# * weights & biases = a tool for tracking all kinds of ml experiments

# %% [markdown]
# ## saving a model
#  two formats to save model
#  * the savedmodel format
#  * hdf5 format

# %%
#savedmodel
model_2.save('best_model')
# Out:
# INFO:tensorflow:Assets written to: best_model/assets

# %%
model_2.save('Best_modelh5.h5')

# %%
#checkmodel by loading it
loaded_savemodel_format = tf.keras.models.load_model('/content/best_model')
loaded_savemodel_format.summary()
#you can compare with prediction
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
#load h5
loaded_h5 = tf.keras.models.load_model('/content/Best_modelh5.h5')
loaded_h5.summary()
#check prediction match..
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##download files from google colab
# * normal right click and download
# * by code
# * google drive

# %%
#by code
from google.colab import files
files.download('/content/Best_modelh5.h5')
